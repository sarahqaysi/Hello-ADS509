# %% [markdown]
# # ADS 509 Module 1: APIs and Web Scraping
# ## Sarah Alqaysi
#
# This notebook has three parts. In the first part you will pull data from the Twitter API. In the second, you will scrape lyrics from AZLyrics.com. In the last part, you'll run code that verifies the completeness of your data pull.
#
# For this assignment you have chosen two musical artists who have at least 100,000 Twitter followers and 20 songs with lyrics on AZLyrics.com. In this part of the assignment we pull the some of the user information for the followers of your artist and store them in text files.

# %% [markdown]
# ## General Assignment Instructions
#
# These instructions are included in every assignment, to remind you of the coding standards for the class. Feel free to delete this cell after reading it.
#
# One sign of mature code is conforming to a style guide. We recommend the [Google Python Style Guide](https://google.github.io/styleguide/pyguide.html). If you use a different style guide, please include a cell with a link.
#
# Your code should be relatively easy-to-read, sensibly commented, and clean. Writing code is a messy process, so please be sure to edit your final submission. Remove any cells that are not needed or parts of cells that contain unnecessary code. Remove inessential `import` statements and make sure that all such statements are moved into the designated cell.
#
# Make use of non-code cells for written commentary. These cells should be grammatical and clearly written. In some of these cells you will have questions to answer. The questions will be marked by a "Q:" and will have a corresponding "A:" spot for you. *Make sure to answer every question marked with a `Q:` for full credit.*

# %% [markdown]
# # Twitter API Pull

# %%
# for the twitter section
import tweepy
import os
import datetime
import re
from pprint import pprint

# for the lyrics scrape section
import requests
import time
from bs4 import BeautifulSoup
from collections import defaultdict, Counter

# %%
# Use this cell for any import statements you add

import warnings

# Suppress warning messages
warnings.filterwarnings('ignore')

#!pip install git+https://github.com/tweepy/tweepy.git

# %% [markdown]
# We need bring in our API keys. Since API keys should be kept secret, we'll keep them in a file called `api_keys.py`. This file should be stored in the directory where you store this notebook. The example file is provided for you on Blackboard. The example has API keys that are _not_ functional, so you'll need to get Twitter credentials and replace the placeholder keys.

# %%
from api_keys import api_key, api_key_secret, bearer_token

# %%
auth = tweepy.AppAuthHandler(api_key, api_key_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
                 #wait_on_rate_limit_notify=True)

print ('API Host', api.host)
#print ('API Version', api.api_root)
# Out:
# API Host api.twitter.com

# %% [markdown]
# ## Testing the API
#
# The Twitter APIs are quite rich. Let's play around with some of the features before we dive into this section of the assignment. For our testing, it's convenient to have a small data set to play with. We will seed the code with the handle of John Chandler, one of the instructors in this course. His handle is `@37chandler`. Feel free to use a different handle if you would like to look at someone else's data.
#
# We will write code to explore a few aspects of the API:
#
# 1. Pull all the follower IDs for @katymck.
# 1. Explore the user object, which gives us information about Twitter users.
# 1. Pull some user objects for the followers.
# 1. Pull the last few tweets by @katymck.

# %%
client = tweepy.Client(bearer_token,wait_on_rate_limit=True)

# %%
handle = "37chandler"
user_obj = client.get_user(username=handle)

followers = client.get_users_followers(
    # Learn about user fields here: 
    # https://developer.twitter.com/en/docs/twitter-api/data-dictionary/object-model/user
    user_obj.data.id, user_fields=["created_at","description","location",
                                   "public_metrics"]
)

# %% [markdown]
# We have the follower IDs, which are unique numbers identifying the user, but we'd like to get some more information on these users. Twitter allows us to pull "fully hydrated user objects", which is a fancy way of saying "all the information about the user". Let's look at user object for our starting handle.

# %%
api = tweepy.API(auth)
user = api.get_user(screen_name='handle')

print(user._json)
# Out:
# {'id': 382247773, 'id_str': '382247773', 'name': 'Handle', 'screen_name': 'Handle', 'location': 'San Francisco, CA', 'profile_location': None, 'description': 'We believe in getting the most out of our time, and saw that one of the most-used tools on the planet, the email inbox, was failing us. Re-Branding!', 'url': 'https://t.co/sQdLIf7LR3', 'entities': {'url': {'urls': [{'url': 'https://t.co/sQdLIf7LR3', 'expanded_url': 'http://handle.today', 'display_url': 'handle.today', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 0, 'listed_count': 0, 'created_at': 'Thu Sep 29 18:53:39 +0000 2011', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 10, 'lang': None, 'status': {'created_at': 'Mon Apr 08 12:05:42 +0000 2019', 'id': 1115224193715466240, 'id_str': '1115224193715466240', 'text': '@brucedaisley It’s not published yet, will be April 10th! We could link you when it’s live! How’s that sound?', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'brucedaisley', 'name': 'Bruce Daisley', 'id': 18768473, 'id_str': '18768473', 'indices': [0, 13]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1115223507552673794, 'in_reply_to_status_id_str': '1115223507552673794', 'in_reply_to_user_id': 18768473, 'in_reply_to_user_id_str': '18768473', 'in_reply_to_screen_name': 'brucedaisley', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 2, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'EFEBDD', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1114896167458836480/U6DSfeuy_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1114896167458836480/U6DSfeuy_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/382247773/1554656190', 'profile_link_color': 'ABB8C2', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}

# %% [markdown]
# Let's pull some more user fields and take a look at them. The fields can be specified in the `user_fields` argument.

# %%
response = client.get_user(id=user_obj.data.id,
                          user_fields=["created_at","description","location",
                                       "entities","name","pinned_tweet_id","profile_image_url",
                                       "verified","public_metrics"])

# %%
for field, value in response.data.items() :
    print(f"for {field} we have {value}")
# Out:
# for username we have 37chandler
# for id we have 33029025
# for verified we have False
# for description we have He/Him. Data scientist, urban cyclist, educator, erstwhile frisbee player.
#
# ¯\_(ツ)_/¯
# for profile_image_url we have https://pbs.twimg.com/profile_images/2680483898/b30ae76f909352dbae5e371fb1c27454_normal.png
# for name we have John Chandler
# for location we have MN
# for created_at we have 2009-04-18 22:08:22+00:00
# for public_metrics we have {'followers_count': 189, 'following_count': 574, 'tweet_count': 945, 'listed_count': 3}

# %% [markdown]
# Now let's explore these a bit. We'll start by printing out names, locations, following count, and followers count for these users.

# %%
num_to_print = 20

for idx, user in enumerate(followers.data) :
    following_count = user.public_metrics['following_count']
    followers_count = user.public_metrics['followers_count']
    
    print(f"{user.name} lists '{user.location}' as their location.")
    print(f" Following: {following_count}, Followers: {followers_count}.")
    print()
    
    if idx >= (num_to_print - 1) :
        break
# Out:
# Steve lists 'I'm over here.' as their location.
#  Following: 1548, Followers: 33.
#
# John O'Connor 🇺🇦 lists 'None' as their location.
#  Following: 8, Followers: 1.
#
# CodeGrade lists 'Amsterdam' as their location.
#  Following: 2712, Followers: 389.
#
# Cleverhood lists 'Providence, RI' as their location.
#  Following: 2775, Followers: 3370.
#
# Paul Naish lists 'Oxford' as their location.
#  Following: 19365, Followers: 19549.
#
# Regina 🚲🌳 (end car supremacy) lists 'Minneapolis' as their location.
#  Following: 2652, Followers: 2790.
#
# Eric Hallstrom lists 'Missoula, MT' as their location.
#  Following: 458, Followers: 304.
#
# Tyler 📊 🐕 🚲 lists 'None' as their location.
#  Following: 440, Followers: 48.
#
# The Center for Community Ownership (CCO) lists 'None' as their location.
#  Following: 47, Followers: 31.
#
# Deepak Chauhan lists 'None' as their location.
#  Following: 575, Followers: 31.
#
# Patsy lists 'Seattle, WA' as their location.
#  Following: 153, Followers: 15.
#
# andrew lists 'St Paul, MN' as their location.
#  Following: 1365, Followers: 464.
#
# Ada Smith lists 'None' as their location.
#  Following: 257, Followers: 183.
#
# Stacey Burns lists 'Minneapolis Witch District' as their location.
#  Following: 4464, Followers: 10557.
#
# Minneapolis Bike Trails lists 'Minneapolis, MN' as their location.
#  Following: 186, Followers: 223.
#
# Kiki Hubbard lists 'Missoula, MT' as their location.
#  Following: 427, Followers: 225.
#
# Erica Zurek lists 'Missoula, MT' as their location.
#  Following: 1163, Followers: 221.
#
# evelindylan lists 'None' as their location.
#  Following: 68, Followers: 2.
#
# Beth Fraser (she/her) lists 'Saint Paul, MN' as their location.
#  Following: 578, Followers: 271.
#
# Jenni Graff lists 'Montana' as their location.
#  Following: 1079, Followers: 180.

# %% [markdown]
# Let's find the person who follows this handle who has the most followers.

# %%
max_followers = 0

for idx, user in enumerate(followers.data) :
    followers_count = user.public_metrics['followers_count']
    
    if followers_count > max_followers :
        max_followers = followers_count
        max_follower_user = user

        
print(max_follower_user)
print(max_follower_user.public_metrics)
# Out:
# JeffreyHayzlett
# {'followers_count': 533219, 'following_count': 444897, 'tweet_count': 47991, 'listed_count': 5650}

# %% [markdown]
# Now a few questions for you about the user object.
#
# Q: How many fields are being returned in the \_json portion of the user object?
#
# A: Nine
#
# ---
#
# Q: Are any of the fields within the user object non-scaler? TK correct term
#
# A: Yes.
#
# ---
#
# Q: How many friends, followers, favorites, and statuses does this user have?
#
# A: {'followers_count': 533219, 'following_count': 444897, 'tweet_count': 47991, 'listed_count': 5650}

# %% [markdown]
# We can map the follower IDs onto screen names by accessing the screen_name key within the user object. Modify the code below to also print out how many people the follower is following and how many followers they have.

# %%
followers = []
api.lookup_users(screen_name = handle)
# Out:
# [User(_api=<tweepy.api.API object at 0x000001998D7BFE48>, _json={'id': 287253599, 'id_str': '287253599', 'name': 'Blair', 'screen_name': '3', 'location': 'London, England', 'description': 'Is it Friday yet?', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 154752, 'friends_count': 102, 'listed_count': 3223, 'created_at': 'Sun Apr 24 16:36:42 +0000 2011', 'favourites_count': 91, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 2152, 'lang': None, 'status': {'created_at': 'Sat Jan 16 08:40:16 +0000 2021', 'id': 1350362220304031744, 'id_str': '1350362220304031744', 'text': 'My favourite player of all time. Absolute legend. Excited for his new career. Would love to see him back in the Pre… https://t.co/dLXtvsfqXr', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/dLXtvsfqXr', 'expanded_url': 'https://twitter.com/i/web/status/1350362220304031744', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for iΟS</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': True, 'quoted_status_id': 1350141755396661248, 'quoted_status_id_str': '1350141755396661248', 'retweet_count': 264, 'favorite_count': 463, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '131516', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/928296111781089280/zkS5bXtk_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/928296111781089280/zkS5bXtk_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/287253599/1449336075', 'profile_link_color': '404040', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'regular', 'withheld_in_countries': []}, id=287253599, id_str='287253599', name='Blair', screen_name='3', location='London, England', description='Is it Friday yet?', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=154752, friends_count=102, listed_count=3223, created_at=datetime.datetime(2011, 4, 24, 16, 36, 42, tzinfo=datetime.timezone.utc), favourites_count=91, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=2152, lang=None, status=Status(_api=<tweepy.api.API object at 0x000001998D7BFE48>, _json={'created_at': 'Sat Jan 16 08:40:16 +0000 2021', 'id': 1350362220304031744, 'id_str': '1350362220304031744', 'text': 'My favourite player of all time. Absolute legend. Excited for his new career. Would love to see him back in the Pre… https://t.co/dLXtvsfqXr', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/dLXtvsfqXr', 'expanded_url': 'https://twitter.com/i/web/status/1350362220304031744', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for iΟS</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo':  ...
#  User(_api=<tweepy.api.API object at 0x000001998D7BFE48>, _json={'id': 255226431, 'id_str': '255226431', 'name': '7', 'screen_name': '7', 'location': 'Clifton, NJ', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 38756, 'friends_count': 11, 'listed_count': 53, 'created_at': 'Sun Feb 20 23:05:33 +0000 2011', 'favourites_count': 49, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 15, 'lang': None, 'status': {'created_at': 'Tue Apr 12 21:55:19 +0000 2022', 'id': 1513999229668106242, 'id_str': '1513999229668106242', 'text': 'April showers bring may flowers', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 21, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/677602788004732928/TPCgWFLi_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/677602788004732928/TPCgWFLi_normal.jpg', 'profile_link_color': '000000', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '020812', 'profile_text_color': '2280A9', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'regular', 'withheld_in_countries': []}, id=255226431, id_str='255226431', name='7', screen_name='7', location='Clifton, NJ', description='', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=38756, friends_count=11, listed_count=53, created_at=datetime.datetime(2011, 2, 20, 23, 5, 33, tzinfo=datetime.timezone.utc), favourites_count=49, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=15, lang=None, status=Status(_api=<tweepy.api.API object at 0x000001998D7BFE48>, _json={'created_at': 'Tue Apr 12 21:55:19 +0000 2022', 'id': 1513999229668106242, 'id_str': '1513999229668106242', 'text': 'April showers bring may flowers', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 21, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 4, 12, 21, 55, 19, tzinfo=datetime.timezone.utc), id=1513999229668106242, id_str='1513999229668106242', text='April showers bring may flowers', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=1, favorite_count=21, favorited=False, retweeted=False, lang='en'), ...
#  User(_api=<tweepy.api.API object at 0x000001998D7BFE48>, _json={'id': 11924252, 'id_str': '11924252', 'name': 'Helgi Þorbjörnsson', 'screen_name': 'h', 'location': 'San Francisco, CA', 'description': 'Chief Architect at @ForgeRock - Formerly Principal Infrastructure Architect @mulesoft/@salesforce and @engineyard / @opendeis - co-founded Orchestra Platform', 'url': 'https://t.co/lJV9m77HaA', 'entities': {'url': {'urls': [{'url': 'https://t.co/lJV9m77HaA', 'expanded_url': 'http://www.helgi.ws', 'display_url': 'helgi.ws', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 41038, 'friends_count': 0, 'listed_count': 823, 'created_at': 'Mon Jan 07 01:17:28 +0000 2008', 'favourites_count': 110, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 10810, 'lang': None, 'status': {'created_at': 'Thu Aug 13 22:34:15 +0000 2020', 'id': 1294039591142354944, 'id_str': '1294039591142354944', 'text': '@ErgoDoxEZ @burdzwastaken @tenderlove The anticipation is killing me! o_O', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'ErgoDoxEZ', 'name': 'ErgoDox EZ', 'id': 3070216592, 'id_str': '3070216592', 'indices': [0, 10]}, {'screen_name': 'burdzwastaken', 'name': 'burdz:x:1000:1000', 'id': 2891644033, 'id_str': '2891644033', 'indices': [11, 25]}, {'screen_name': 'tenderlove', 'name': 'Aaron Patterson', 'id': 14761655, 'id_str': '14761655', 'indices': [26, 37]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1294036580848607240, 'in_reply_to_status_id_str': '1294036580848607240', 'in_reply_to_user_id': 3070216592, 'in_reply_to_user_id_str': '3070216592', 'in_reply_to_screen_name': 'ErgoDoxEZ', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 9, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1378936521374330882/mwcxb9ox_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1378936521374330882/mwcxb9ox_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/11924252/1617598606', 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'regular', 'withheld_in_countries': []}, id=11924252, id_str='11924252', name='Helgi Þorbjörnsson', screen_name='h', location='San Francisco, CA', description='Chief Architect at @ForgeRock - Formerly Principal Infrastructure Architect @mulesoft/@salesforce and @engineyard / @opendeis - co-founded Orchestra Platform', url='https://t.co/lJV9m77HaA', entities={'url': {'urls': [{'url': 'https://t.co/lJV9m77HaA', 'expanded_url': 'http://www.helgi.ws', 'display_url': 'helgi.ws', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=41038, friends_count=0, listed_count=823, created_at=datetime.datetime(2008, 1, 7, 1, 17, 28, tzinfo=datetime.timezone.utc), favourites_count=110, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=10810, lang=None, status=Status(_api=<tweepy.api.API object at 0x000001998D7BFE48>, _json={'created_at': 'Thu Aug 13 22:34:15 +0000 2020', 'id': 1294039591142354944, 'id_str': '1294039591142354944', 'text': '@E ...
#  User(_api=<tweepy.api.API object at 0x000001998D7BFE48>, _json={'id': 940631, 'id_str': '940631', 'name': 'Andrei Zmievski', 'screen_name': 'a', 'location': 'Seattle, WA', 'description': 'Coder, foodie, photographer, relentless traveler. Seattlelite. 🇷🇺/🇺🇸', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 137922, 'friends_count': 323, 'listed_count': 2141, 'created_at': 'Sun Mar 11 18:05:57 +0000 2007', 'favourites_count': 824, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 14971, 'lang': None, 'status': {'created_at': 'Wed May 18 08:21:56 +0000 2022', 'id': 1526840497955713026, 'id_str': '1526840497955713026', 'text': 'RT @PadmaLakshmi: Questions for the people who are scared of becoming a minority: Why is that? Are minorities treated differently?', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'PadmaLakshmi', 'name': 'Padma Lakshmi', 'id': 57371662, 'id_str': '57371662', 'indices': [3, 16]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon May 16 14:20:09 +0000 2022', 'id': 1526205871646248961, 'id_str': '1526205871646248961', 'text': 'Questions for the people who are scared of becoming a minority: Why is that? Are minorities treated differently?', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 40901, 'favorite_count': 271912, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'is_quote_status': False, 'retweet_count': 40901, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '170F00', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/448301181324894208/vqY_gIaL_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/448301181324894208/vqY_gIaL_normal.jpeg', 'profile_link_color': 'A04521', 'profile_sidebar_border_color': 'E6AA51', 'profile_sidebar_fill_color': 'E6AA51', 'profile_text_color': '170F00', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'regular', 'withheld_in_countries': []}, id=940631, id_str='940631', name='Andrei Zmievski', screen_name='a', location='Seattle, WA', description='Coder, foodie, photographer, relentless traveler. Seattlelite. 🇷🇺/🇺🇸', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=137922, friends_count=323, listed_count=2141, created_at=datetime.datetime(2007, 3, 11, 18, 5, 57, tzinfo=datetime.timezone.utc), favourites_count=824, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=14971, lang=None, status=Status(_api=<tweepy.api.API object at 0x000001998D7BFE48>, _json={'created_at': 'Wed May 18 08:21:56 +0000 2022', 'id': 1526840497955713026, 'id_str': '1526840497955713026', 'text': 'RT @PadmaLakshmi: Question ...
#  User(_api=<tweepy.api.API object at 0x000001998D7BFE48>, _json={'id': 863391, 'id_str': '863391', 'name': 'Naoki  Hiroshima', 'screen_name': 'N', 'location': 'The Bay Area', 'description': 'My life goal is to live long enough to see @AOC becoming the President.', 'url': 'https://t.co/HJOLIypL0u', 'entities': {'url': {'urls': [{'url': 'https://t.co/HJOLIypL0u', 'expanded_url': 'https://medium.com/p/24eb09e026dd', 'display_url': 'medium.com/p/24eb09e026dd', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 91192, 'friends_count': 71, 'listed_count': 933, 'created_at': 'Sat Mar 10 06:35:22 +0000 2007', 'favourites_count': 2696, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 17747, 'lang': None, 'status': {'created_at': 'Tue May 17 13:47:04 +0000 2022', 'id': 1526559932367024129, 'id_str': '1526559932367024129', 'text': '@kenn @Dalle2Pics まほうと くべつが つかんね。', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'kenn', 'name': 'Kenn Ejima', 'id': 711493, 'id_str': '711493', 'indices': [0, 5]}, {'screen_name': 'Dalle2Pics', 'name': 'Dalle2 Pics', 'id': 1257925415307485184, 'id_str': '1257925415307485184', 'indices': [6, 17]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1526435763751374849, 'in_reply_to_status_id_str': '1526435763751374849', 'in_reply_to_user_id': 711493, 'in_reply_to_user_id_str': '711493', 'in_reply_to_screen_name': 'kenn', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'ja'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '0A0B0A', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/951463238/self.120x120.108kb_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/951463238/self.120x120.108kb_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/863391/1497049324', 'profile_link_color': '356420', 'profile_sidebar_border_color': '020303', 'profile_sidebar_fill_color': '122B08', 'profile_text_color': '366422', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'regular', 'withheld_in_countries': []}, id=863391, id_str='863391', name='Naoki  Hiroshima', screen_name='N', location='The Bay Area', description='My life goal is to live long enough to see @AOC becoming the President.', url='https://t.co/HJOLIypL0u', entities={'url': {'urls': [{'url': 'https://t.co/HJOLIypL0u', 'expanded_url': 'https://medium.com/p/24eb09e026dd', 'display_url': 'medium.com/p/24eb09e026dd', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=91192, friends_count=71, listed_count=933, created_at=datetime.datetime(2007, 3, 10, 6, 35, 22, tzinfo=datetime.timezone.utc), favourites_count=2696, utc_offset=None, time_zone=None, geo_enabled=True, verified=True, statuses_count=17747, lang=None, status=Status(_api=<tweepy.api.API object at 0x000001998D7BFE48>, _json={'created_at': 'Tue May 17 13:47:04 +0000 2022', 'id': 1526559932367024129, 'id_str': '1526559932367024129', 'text': '@kenn @Dalle2Pics まほうと くべつが つかんね。', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'kenn', 'name': 'Kenn Ejima', 'id': 711493, 'id_str': '711493', 'indices': [0, 5]}, {'screen_name': 'Dalle2Pics', 'name': 'Dalle2 Pics', 'id': 1257925415307485184, 'id_str': '125 ...
#  User(_api=<tweepy.api.API object at 0x000001998D7BFE48>, _json={'id': 50465434, 'id_str': '50465434', 'name': 'I have but one letter. It is L. 🇺🇦', 'screen_name': 'L', 'location': 'Maldives', 'description': 'Move along. Nothing to see here. Not for sale. For anything else, take your chances and try me here: SingleLetter@protonmail.com', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': True, 'followers_count': 1, 'friends_count': 1, 'listed_count': 280, 'created_at': 'Wed Jun 24 22:37:07 +0000 2009', 'favourites_count': 3, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 328, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '642D8B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1289716771889397761/EOcMBkF6_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1289716771889397761/EOcMBkF6_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/50465434/1594938882', 'profile_link_color': 'FA743E', 'profile_sidebar_border_color': '65B0DA', 'profile_sidebar_fill_color': '27719C', 'profile_text_color': '573710', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'regular', 'withheld_in_countries': []}, id=50465434, id_str='50465434', name='I have but one letter. It is L. 🇺🇦', screen_name='L', location='Maldives', description='Move along. Nothing to see here. Not for sale. For anything else, take your chances and try me here: SingleLetter@protonmail.com', url=None, entities={'description': {'urls': []}}, protected=True, followers_count=1, friends_count=1, listed_count=280, created_at=datetime.datetime(2009, 6, 24, 22, 37, 7, tzinfo=datetime.timezone.utc), favourites_count=3, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=328, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='642D8B', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=True, profile_image_url='http://pbs.twimg.com/profile_images/1289716771889397761/EOcMBkF6_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1289716771889397761/EOcMBkF6_normal.jpg', profile_banner_url='https://pbs.twimg.com/profile_banners/50465434/1594938882', profile_link_color='FA743E', profile_sidebar_border_color='65B0DA', profile_sidebar_fill_color='27719C', profile_text_color='573710', profile_use_background_image=True, has_extended_profile=False, default_profile=False, default_profile_image=False, following=False, follow_request_sent=None, notifications=None, translator_type='regular', withheld_in_countries=[]),
#  User(_api=<tweepy.api.API object at 0x000001998D7BFE48>, _json={'id': 146733, 'id_str': '146733', 'name': 'Rex Hammock', 'screen_name': 'R', 'location': 'Nashville', 'description': '@smallbusiness', 'url': 'https://t.co/Tr0yOUppLv', 'entities': {'url': {'urls': [{'url': 'https://t.co/Tr0yOUppLv', 'expanded_url': 'http://rexblog.com', 'display_url': 'rexblog.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 39427, 'friends_count': 2057, 'listed_count': 1083, 'created_at': 'Fri Dec 22 04:14:21 +0000 2006', 'favourites_count': 854, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 18895, 'lang': None, 'status': {'created_at': 'Fri Feb 25 19:31:26 +0000 2022', 'id': 1497293177161666560, 'id_str': '1497293177161666560', 'text': '@BeckyMcCray @AdeleMcAlear @chrisbrogan @jowyang @newmediajim Memories.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'BeckyMcCray', 'name': 'Becky McCray', 'id': 10318, 'id_str': '10318', 'indices': [0, 12]}, {'screen_name': 'AdeleMcAlear', 'name': 'Adele McAlear', 'id': 5554222, 'id_str': '5554222', 'indices': [13, 26]}, {'screen_name': 'chrisbrogan', 'name': 'Chris Brogan/Chief of Staff', 'id': 10202, 'id_str': '10202', 'indices': [27, 39]}, {'screen_name': 'jowyang', 'name': 'Jeremiah Owyang jowyang.eth', 'id': 79543, 'id_str': '79543', 'indices': [40, 48]}, {'screen_name': 'newmediajim', 'name': 'Jim Long', 'id': 10419, 'id_str': '10419', 'indices': [49, 61]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1497288501297139720, 'in_reply_to_status_id_str': '1497288501297139720', 'in_reply_to_user_id': 10318, 'in_reply_to_user_id_str': '10318', 'in_reply_to_screen_name': 'BeckyMcCray', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 3, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/3161626332/a64daa407da2f6ab4d5b08c440aaa044_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3161626332/a64daa407da2f6ab4d5b08c440aaa044_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/146733/1568390283', 'profile_link_color': '006CF0', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'FFFFFF', 'profile_text_color': '000405', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'regular', 'withheld_in_countries': []}, id=146733, id_str='146733', name='Rex Hammock', screen_name='R', location='Nashville', description='@smallbusiness', url='https://t.co/Tr0yOUppLv', entities={'url': {'urls': [{'url': 'https://t.co/Tr0yOUppLv', 'expanded_url': 'http://rexblog.com', 'display_url': 'rexblog.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=39427, friends_count=2057, listed_count=1083, created_at=datetime.datetime(2006, 12, 22, 4, 14, 21, tzinfo=datetime.timezone.utc), favourites_count=854, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=18895, lang=None, status=Status(_api=<tweepy.api.API object at 0x000001998D7BFE48>, _json={'created_at': 'Fri Feb 25 19:31:26 +0000 2022', 'id': 1497293177161666560, 'id_str': '1497293177161666560', 'text': '@BeckyMcCray @AdeleMcAlear @chrisbrogan @jowyang @newmediajim Memori ...

# %%
# fetching the favourites_count for "37chandler"
favourites_count = user.favourites_count

# fetching the statuses_count for "37chandler"
statuses_count = user.statuses_count
  
print("The number of tweets the user has liked are : " + str(favourites_count))
print("The number of statuses the user has had are : " + str(statuses_count))
# Out:
# The number of tweets the user has liked are : 1786
# The number of statuses the user has had are : 8731

# %%
# finding the count of how many followers & friends "37chandler" has

# fetching the user
user = api.get_user(screen_name='37chandler')
  
# fetching the followers_count
followers_count = user.followers_count

# fetching the friends_count
friends_count = user.friends_count

  
print("The number of followers of 37chandler are : " + str(followers_count))
print("The number of friends of 37chandler are : " + str(friends_count))
# Out:
# The number of followers of 37chandler are : 189
# The number of friends of 37chandler are : 574

# %%
# Add code here to print out friends and followers of `handle`

for user in tweepy.Cursor(api.get_followers, screen_name="37chandler").items():
    print('followers: ' + user.screen_name)

for user in tweepy.Cursor(api.get_friends, screen_name="37chandler").items():
    print('friends: ' + user.screen_name)
# Out:
# followers: HicSvntDraconez
# followers: JohnOCo70713197
# followers: CodeGradeCom
# followers: cleverhoods
# followers: PaulNaish78
# followers: mplsFietser
# followers: echallstrom
# followers: byler_t117
# followers: Community_Owner
# followers: DeepakC64237257
# followers: patsy16sb
# followers: andrewc186
# followers: _ada_smith
# followers: WentRogue
# followers: MplsBikeTrails
# followers: KristinaHubbard
# followers: erica_zurek
# followers: evelindylan1
# followers: yofraze
# followers: JenniJenniG
# followers: RisaForParks
# followers: l7ashley
# followers: dodgemc
# followers: oldschoolCUT
# followers: TMolteni
# followers: MeredithWestin
# followers: metageniglobal
# followers: scoover
# followers: QuonkQuonk
# followers: rickbruner
# followers: peterschmitt34
# followers: stalinnaveen
# followers: afhauer
# followers: mediantweets
# followers: gregtenold
# followers: MadameDavey
# followers: freyjahartz
# followers: johnlouisM
# followers: FenrisWinston
# followers: CogentAg
# followers: Worse_Reviewer
# followers: puadmsara
# followers: davebts77
# followers: ntstuart25
# followers: bk_edge
# followers: Mediastruction
# followers: Amit_Levinson
# followers: HDAmeliaP
# followers: louisesaycheese
# followers: Metcalf_Lab
# followers: hannahleomt
# followers: MaryVranicar
# followers: data_marty
# followers: AbNechar
# followers: chuck_aw
# followers: BooksandBars
# followers: WedgeLIVE
# followers: ben_j_lindsay
# followers: ovative
# followers: fkinglag
# followers: DanMarStP
# followers: chrisjohnmeyer
# followers: refundpolicy
# followers: Ross_Dahlke
# followers: ahgoff
# followers: joranelias
# followers: biwah
# followers: BruneauMT
# followers: UMontanaBiz
# followers: theRealist_EG
# followers: mitreboxmpls
# followers: UltimateCentral
# followers: frenchel
# followers: benbanyas
# followers: Rachel_Rabaey
# followers: ANewAnglePod
# followers: almostharvard
# followers: mayadusenbery
# followers: Muzie76
# followers: hellonanders
# followers: JaysonBarker89
# followers: gtenold
# followers: The_John_Foster
# followers: paintmessenger
# followers: samkanner
# followers: WilhelmSixTwo
# followers: bad_foodblogger
# followers: JanusUltimate
# followers: mfrank406
# followers: anna_marbut
# followers: okhormali
# followers: cgrammier
# followers: paigeabowen
# followers: StatSkier
# followers: mrtgrnt37
# followers: laviedelareine
# followers: tomfoolery_j
# followers: CarbaughCurt
# followers: JeffreyHayzlett
# followers: benmarccohen
# followers: PacoMarkE
# followers: marybob54
# followers: niklaasdumroese
# followers: assy237
# followers: RaelinJaqueth
# followers: TILTMPLS
# followers: UltiPhotos
# followers: d_a_v_i_s___
# followers: jakkimohr
# followers: SchmitElliot
# followers: CoachJohnjohn16
# followers: mcconnell_nate
# followers: Pmkurtz
# followers: tmcummins_mt
# followers: DataDames
# followers: Montandaluz
# followers: benchandler
# followers: apoplecticfit
# followers: geoflianalytics
# followers: sbcmvp
# followers: kevkevwopwop
# followers: SeaCay
# followers: SchuIzke
# followers: shanacarp
# followers: janneformpls
# followers: GraceMolteni
# followers: Moab200
# followers: emib4268
# followers: outsidewide
# followers: BrasellRobert
# followers: simplesanj
# followers: RuthCurry
# followers: adrianaquiros
# followers: TheMindyProject
# followers: garrickin
# followers: padre_angle
# followers: timmy930
# followers: ColdCutsUlt
# followers: sporty1340
# followers: MckeanTyler
# followers: fakephilsgood
# followers: ChaunceyKeepers
# followers: SurlyCynicUlt
# followers: lemster047
# followers: devsebby
# followers: eileencmurray
# followers: angel28117026
# followers: JohnFenske
# followers: MeganMolteni
# followers: brianrupert
# followers: marisabrandt
# followers: matt3reid
# followers: LtotheOhman
# followers: SquallUltimate
# followers: SenseAi_Co
# followers: DelauJody
# followers: brickyard__
# followers: rgbysgt
# followers: doublepower
# followers: TCUL_Official
# followers: BoneyardUlt
# followers: MLukeSmith
# followers: giessel
# followers: isaacro
# followers: TSevert
# followers: Reckonultimate
# followers: FCStourney
# followers: tyhenkaline
# followers: bknystrom
# followers: ClimaxUltimate
# followers: Turkish01
# followers: Skyner34
# followers: Sambobroberts
# followers: ChandlerJohnA
# followers: ChepeH
# followers: SurlyUltimate
# followers: SuePeaseBanitt
# followers: tcwomensmasters
# followers: grizzlyjenny
# followers: GoodGuysToKnow
# followers: Mark_Rippetoe
# followers: DanMcAdam
# followers: pigglediggle
# followers: geobeek4
# followers: MorrisMartin
# followers: lifesizemind
# followers: MemphisMusick
# followers: ShimritMarkette
# followers: nikkicool07378
# friends: abmakulec
# friends: ArtButSports
# friends: nhannahjones
# friends: wonderofscience
# friends: beesolved
# friends: cleverhoods
# friends: TheLincoln
# friends: M_WrenchGang
# friends: hewhoholdsfast
# friends: USGS_DataSci
# friends: davidshor
# friends: MplsWard2
# friends: depthsofwiki
# friends: philgaimon
# friends: mplsFietser
# friends: egabbert
# friends: TheWarOnCars
# friends: BillLindeke
# friends: Community_Owner
# friends: ElonJet
# friends: AmeliaMN
# friends: dino_comics
# friends: CorgiEveryHour
# friends: LeonKauffman
# friends: BurgartBioethix
# friends: AshleyAsmus
# friends: RaxKingIsDead
# friends: doomscroll_bot
# friends: rebeccamakkai
# friends: PourquoiPasToi
# friends: WorldBollard
# friends: JohnBauters
# friends: karlrohe
# friends: xkcdComic
# friends: HerveLeTellier
# friends: MplsBikeTrails
# friends: KristinaHubbard
# friends: laurakolbemd
# friends: CCriadoPerez
# friends: kaceyjohansing
# friends: MattPinder1
# friends: _ada_smith
# friends: AnneChameau
# friends: MplsPhotoBot
# friends: brandicarlile
# friends: TwoSuns3
# friends: RabalFrancesco
# friends: MaraRiv2
# friends: ziyatong
# friends: susanorlean
# friends: erica_zurek
# friends: SantaErik
# friends: yofraze
# friends: blkgarnetbooks
# friends: birchbarkbooks
# friends: nlyonne
# friends: BenStiller
# friends: NeilKuMD
# friends: heatherklus
# friends: year_progress
# friends: SahanJournal
# friends: TheRightCant
# friends: Jopolkadot
# friends: MarlonJames5
# friends: johneapolis
# friends: avocadoplex
# friends: dodgemc
# friends: NWS_NTWC
# friends: MaritsaGeorgiou
# friends: WedgeLIVE4Women
# friends: TMolteni
# friends: cpamzhang
# friends: OhNoSheTwitnt
# friends: scoover
# friends: antgoldbloom
# friends: onthemedia
# friends: regardscoupable
# friends: AltraRunning
# friends: dhmontgomery
# friends: JUULvapor
# friends: rgay
# friends: GeorgeFloydSQ
# friends: michaelharriot
# friends: Aella_Girl
# friends: BicycleHannah
# friends: rickbruner
# friends: peterschmitt34
# friends: pronounced_ing
# friends: RisaForParks
# friends: auren
# friends: BadMedicalTakes
# friends: freyjahartz
# friends: blgtylr
# friends: midwestern_ope
# friends: FenrisWinston
# friends: juliettekayyem
# friends: deray
# friends: csbarsky
# friends: mcmansionhell
# friends: RottenInDenmark
# friends: Remember_Sarah
# friends: yourewrongabout
# friends: topepos
# friends: _inesmontani
# friends: EffinBirds
# friends: hannahleomt
# friends: ClareMalone
# friends: SlateGabfest
# friends: CT_Bergstrom
# friends: Pmkurtz
# friends: RevTranscripts
# friends: JohnDCook
# friends: nyttypos
# friends: WentRogue
# friends: sarahcpr
# friends: Flowerdarby
# friends: jbouie
# friends: MissoulaCurrent
# friends: puadmsara
# friends: UR_Ninja
# friends: MplsWard10
# friends: MplsWard9
# friends: mrotzie
# friends: MoonPalaceBooks
# friends: OmarJimenez
# friends: legroff
# friends: risahustad
# friends: bad_foodblogger
# friends: rtraister
# friends: samkanner
# friends: Turkish01
# friends: NYTimesWordplay
# friends: Yamiche
# friends: TriciaLockwood
# friends: EmbajadaEEUUcl
# friends: biblioracle
# friends: byjlee
# friends: MinnPost
# friends: lindsmpls
# friends: FixLyndale
# friends: FillmoreMPLS
# friends: biketrouble
# friends: JasonIsbell
# friends: magersandquinn
# friends: b0rk
# friends: SmithCollegeSDS
# friends: HDAmeliaP
# friends: justsaysrisks
# friends: Metcalf_Lab
# friends: menwritewomen
# friends: csittenfeld
# friends: ramoss
# friends: MoreNeighbors
# friends: chuck_aw
# friends: giessel
# friends: ovative
# friends: HumsLiquorMPLS
# friends: josedpacas
# friends: Ross_Dahlke
# friends: justsaysinmice
# friends: CursedArchitect
# friends: tcblockedlanes
# friends: mrtgrnt37
# friends: mplsbikewrath
# friends: nathanwpyle
# friends: fietsprofessor
# friends: petercoffee
# friends: prof_nch
# friends: nona
# friends: QasimRashid
# friends: puddingviz
# friends: ylnt
# friends: meganlathrop1
# friends: behindyourback
# friends: coldxman
# friends: mfrank406
# friends: KateAgnewMN
# friends: CoverSpy
# friends: ANewAnglePod
# friends: nostalgicbroad
# friends: mayadusenbery
# friends: grizzlyjenny
# friends: dog_rates
# friends: JenniJenniG
# friends: kathrynschulz
# friends: MtnWestNews
# friends: bookofthemonth
# friends: robjhyndman
# friends: MerriamWebster
# friends: byjoeeaton
# friends: HarMarSuperstar
# friends: bikinginmpls
# friends: mediantweets
# friends: okhormali
# friends: jakkimohr
# friends: laviedelareine
# friends: Kaepernick7
# friends: tomtomorrow
# friends: SethBodnar
# friends: LeahLibresco
# friends: samfbiddle
# friends: ThriventSR
# friends: Outlier
# friends: elspethreeve
# friends: WillMcAvoyACN
# friends: marybob54
# friends: TDM_StiffOnes
# friends: sbcmvp
# friends: juliasilge
# friends: atlasobscura
# friends: TILTpinballbar
# friends: MinneAnalytics
# friends: d_a_v_i_s___
# friends: beesandbombs
# friends: TimothyDSnyder
# friends: PreetBharara
# friends: mollycrabapple
# friends: Egangoonsquad
# friends: mackab
# friends: KatieMPalmer
# friends: cookiechat4_0
# friends: WIREDScience
# friends: Nate_Cohn
# friends: superwuster
# friends: Sarah_Bakewell
# friends: happifydesign
# friends: ashleyfeinberg
# friends: DarrellEarnest
# friends: TheMorningNews
# friends: mcconnell_nate
# friends: drob
# friends: grok_
# friends: ChandlerJohnA
# friends: clubtrillion
# friends: DataDames
# friends: OpenStreetsMPLS
# friends: OurStreetsMpls
# friends: benchandler
# friends: WangCecillia
# friends: WedgeLIVE
# friends: PemaQuotes
# friends: AniPemaChodron
# friends: thepointsguy
# friends: chrija
# friends: MeredithWestin
# friends: AoDespair
# friends: JonHaidt
# friends: GraceMolteni
# friends: ericgarland
# friends: jackielay
# friends: NBCSportsSoccer
# friends: OfficeGovEthics
# friends: Shteyngart
# friends: billmckibben
# friends: Jeni_Chapman
# friends: UMJSchool
# friends: huttopian
# friends: NewYorker
# friends: bobstaake
# friends: andrewflowers
# friends: simplesanj
# friends: IlhanMN
# friends: MinnesotaUlt
# friends: nicholsonbaker8
# friends: MargaretAtwood
# friends: FOXSoccer
# friends: VanJones68
# friends: BillGates
# friends: gatesfoundation
# friends: ClintonFdn
# friends: TheMindyProject
# friends: TVietor08
# friends: jetjocko
# friends: NWEinfo
# friends: sporty1340
# friends: Cat_McCluskey
# friends: notouchingult
# friends: msladowntown
# friends: EditorObama
# friends: amaumt
# friends: UMontanaBiz
# friends: missoulian
# friends: Missoula_Indy
# friends: umontana
# friends: ConanOBrien
# friends: Thrivent
# friends: saletan
# friends: joshtpm
# friends: angel28117026
# friends: DraughtWorks
# friends: emilynussbaum
# friends: POTUS44
# friends: Kyle_MacLachlan
# friends: RiPhysKin
# friends: padre_angle
# friends: parisreview
# friends: hadleywickham
# friends: StatModeling
# friends: MrGeorgeWallace
# friends: LastWeekTonight
# friends: iamjohnoliver
# friends: iamsambee
# friends: FullFrontalSamB
# friends: SurlyCynicUlt
# friends: TheOnion
# friends: ResearchMark
# friends: piercejessica2
# friends: jon_bois
# friends: NWSMissoula
# friends: kumailn
# friends: HassyHass35
# friends: EastIslesMPLS
# friends: WhittierMN
# friends: jonfavs
# friends: ideamensch
# friends: devsebby
# friends: colsonwhitehead
# friends: UCSandblast
# friends: guerrillault
# friends: UltiProblems
# friends: SenatorTester
# friends: ringer
# friends: tomstyles
# friends: eileencmurray
# friends: UKWorlds
# friends: BlackCoffeeMsla
# friends: AndyRichter
# friends: igorvolsky
# friends: jeela71
# friends: traecrowder
# friends: chronicle
# friends: steminist
# friends: MsMagazine
# friends: GloriaSteinem
# friends: fakedansavage
# friends: bamasecs
# friends: USAUltimateLive
# friends: SchuIzke
# friends: paigeabowen
# friends: SenWarren
# friends: sugarfriss
# friends: norm
# friends: AlbertoCairo
# friends: Casras9
# friends: EverydaySexism
# friends: HopeJahren
# friends: mindykaling
# friends: Snowden
# friends: ev_tracker
# friends: coliobolio
# friends: Coffee_House_
# friends: theunread
# friends: JohnFenske
# friends: benmarccohen
# friends: brianrupert
# friends: maddow
# friends: azizansari
# friends: Sethrogen
# friends: pattonoswalt
# friends: JuddApatow
# friends: ActuallyNPH
# friends: StephenAtHome
# friends: SteveMartinToGo
# friends: michaelpollan
# friends: jonronson
# friends: bradberens
# friends: DonCheadle
# friends: elliottholt
# friends: NWSTwinCities
# friends: AnnaHolmes
# friends: AlecBaldwln____
# friends: marisabrandt
# friends: JuliaBlocher
# friends: johnlegend
# friends: SeanAnonymous
# friends: lisabendermpls
# friends: keithellison
# friends: BetsyHodges
# friends: emilydparker
# friends: BHL
# friends: BHL
# friends: DalaiLama
# friends: AcademicPain
# friends: SixDegreesUp
# friends: matt3reid
# friends: MnDPS_DPS
# friends: LtotheOhman
# friends: johnjodzio
# friends: SquallUltimate
# friends: DelauJody
# friends: rgbysgt
# friends: doublepower
# friends: blobtower
# friends: TCUL_Official
# friends: plamere
# friends: AnagramLLC
# friends: RuthCurry
# friends: EmilyGould
# friends: slicingeyeballs
# friends: abywolf
# friends: KEVINtySixers
# friends: TheRealWknd
# friends: ubcmensultimate
# friends: Burruss14
# friends: BaskaSnaps
# friends: Worse_Reviewer
# friends: SociableCider
# friends: amoryamargo
# friends: gavinkaysen
# friends: MarvelBar
# friends: TravailKitchen
# friends: BachelorFarmer
# friends: spoonandstable
# friends: jeffbellphoto
# friends: erowidrecruiter
# friends: SenseAi_Co
# friends: YEAHRIGHTPOS
# friends: nybooks
# friends: IronyDept
# friends: EatStSocial
# friends: LuciasMpls
# friends: FulcrumPro
# friends: luketimjohnson
# friends: clxbttp
# friends: SarcasticRover
# friends: ThingsBrentSaid
# friends: AcademicsSay
# friends: nytimesbooks
# friends: jessilynnfisher
# friends: TSevert
# friends: LettersOfNote
# friends: TheMarkTwain
# friends: Kurt_Vonnegut
# friends: paintmessenger
# friends: IfIwerejudgingU
# friends: YOURBITTERTRUTH
# friends: bittermens
# friends: CreativeDrunk
# friends: 100percentBS
# friends: scandalultimate
# friends: UG_Seattle
# friends: NightlockUlt
# friends: CoCupTourney
# friends: PacoMarkE
# friends: TheRealJenBrown
# friends: Ness_Duluth
# friends: tbtduluth
# friends: bjnovak
# friends: MLukeSmith
# friends: rogbennett
# friends: embassydavies
# friends: MenInBlazers
# friends: FiveThirtyEight
# friends: 538politics
# friends: propublica
# friends: UpshotNYT
# friends: LocalCurrent
# friends: icehousempls
# friends: the_ARF
# friends: mtpublicradio
# friends: MNYouthUltimate
# friends: NateSilver538
# friends: ericripert
# friends: Bourdain
# friends: RichardBlais
# friends: tomcolicchio
# friends: danielcurme
# friends: jefe23
# friends: WilhelmSixTwo
# friends: Sambobroberts
# friends: onmprnews
# friends: MPR
# friends: MPRweather
# friends: GraywolfPress
# friends: nxwicks
# friends: M_Hedberg
# friends: sethmeyers
# friends: SarahKSilverman
# friends: TracyMorgan
# friends: citypages
# friends: FirstAvenue
# friends: jmessersmith
# friends: readandbreathe
# friends: emilybooks
# friends: isaacro
# friends: therealzipstips
# friends: WedgeAndLHCoop
# friends: MinneapolisSnow
# friends: airfarewatchdog
# friends: thisispolica
# friends: Leioutultimate
# friends: UltiworldStats
# friends: PrideofNY
# friends: jagaynor
# friends: bigmuffnuts
# friends: ektor_jr
# friends: GOATultimate
# friends: SeattleRiot
# friends: BravoUltimate
# friends: HighFiveUlti
# friends: No_Look_Scoober
# friends: angrycatfish
# friends: cloudcarvings
# friends: MeganMolteni
# friends: HeistUltimate
# friends: alfranken
# friends: BarackObama
# friends: Boston_Ironside
# friends: ClimaxUltimate
# friends: MnDOT
# friends: FullFieldHammer
# friends: thereadystate
# friends: Reckonultimate
# friends: burnsideulti
# friends: Skyner34
# friends: TheCurrent
# friends: RocktheGarden
# friends: OregonFugue
# friends: UMNWomensUlti
# friends: TheGentlemenNCR
# friends: rstudio
# friends: tyhenkaline
# friends: dragNthrust
# friends: R_T_Rybak
# friends: MiddPranksterz
# friends: pjprial
# friends: SubZeroUltimate
# friends: joshmc37
# friends: mnwindchill
# friends: Ultiworldlive
# friends: USAUltimateWG
# friends: CKlosterman
# friends: MaidJaneBirch
# friends: samuelpepys
# friends: Middlebury
# friends: UltiPhotos
# friends: Ultiworld
# friends: ngnultimate
# friends: hodaglove
# friends: mnultimate
# friends: StatSkier
# friends: USAUltimate
# friends: SyzygyUltimate
# friends: SurlyUltimate
# friends: BooksandBars
# friends: skydmagazine
# friends: tcwomensmasters
# friends: pranksters69
# friends: AlumniGame
# friends: Ardee33
# friends: 1Duck1Love
# friends: lemster047
# friends: DanMcAdam
# friends: MorrisMartin
# friends: geobeek4
# friends: Shanehoe
# friends: TrueHoop
# friends: johnhollinger
# friends: ChepeH
# friends: FuriousUltimate
# friends: doublewidetx
# friends: flycoons
# friends: surlybrewing
# friends: pigglediggle
# friends: jasonmustian
# friends: adamlisagor
# friends: fakephilsgood
# friends: tylerkinley
# friends: ecultimate
# friends: ATLchain
# friends: MemphisMusick
# friends: cutrules
# friends: license2chill01
# friends: MiddPranksters
# friends: johnwelbourn

# %% [markdown]
# Although you won't need it for this assignment, individual tweets (called "statuses" in the API) can be a rich source of text-based data. To illustrate the concepts, let's look at the last few tweets for this user. You are encouraged to explore the `status` object and marvel in the richness of the data that is available.

# %%
tweet_count = 0

for status in tweepy.Cursor(api.user_timeline, id=handle).items():
    tweet_count += 1
    
    print(f"The tweet was tweeted at {status.created_at}.")
    print(f"The original tweet has been retweeted {status.retweet_count} times.")
    
    clean_status = status.text
    clean_status = clean_status.replace("\n"," ")
    
    print(f"{clean_status}")
    print("\n"*2)
        
    if tweet_count > 10 :
        break
# Out:
# Unexpected parameter: id
# The tweet was tweeted at 2022-05-18 19:43:54+00:00.
# The original tweet has been retweeted 86 times.
# RT @cleoabram: for my latest video on dog anti-aging (!), I asked the Huge If True audience to send me photos of their dogs as puppies v. o…
#
#
#
# The tweet was tweeted at 2022-05-18 12:13:27+00:00.
# The original tweet has been retweeted 2902 times.
# RT @spiantado: Here is why IQ is bullshit.    A thread.
#
#
#
# The tweet was tweeted at 2022-05-18 12:04:11+00:00.
# The original tweet has been retweeted 1 times.
# Great work, Luke. Thanks to @UMontanaBiz for the support to work on this. https://t.co/29sDihvt2F
#
#
#
# The tweet was tweeted at 2022-05-17 12:43:53+00:00.
# The original tweet has been retweeted 36 times.
# RT @EffinBirds: I was walking @TheWebbyAwards red carpet with Effin’ Birds newsletter writer @michellemanafy when @BigBird showed up.   htt…
#
#
#
# The tweet was tweeted at 2022-05-13 23:46:46+00:00.
# The original tweet has been retweeted 5 times.
# RT @johnhollinger: @NateSilver538 Atlanta still leads the nation in "further West than you think"
#
#
#
# The tweet was tweeted at 2022-05-13 12:03:18+00:00.
# The original tweet has been retweeted 1487 times.
# RT @tomscocca: It was helpful to talk with @pareene about the experience of turning away from one of the most comfortable default beliefs o…
#
#
#
# The tweet was tweeted at 2022-05-12 14:41:18+00:00.
# The original tweet has been retweeted 187 times.
# RT @JamesTateHill: I Actually Thought You Had Dropped the Class: A Memoir of Your Final Grade
#
#
#
# The tweet was tweeted at 2022-05-12 12:19:43+00:00.
# The original tweet has been retweeted 0 times.
# @BluehairCoffee @WedgeLIVE I try to always take a pic of it. https://t.co/7i4nIgBKFM
#
#
#
# The tweet was tweeted at 2022-05-12 03:18:56+00:00.
# The original tweet has been retweeted 0 times.
# @LiberalwKnives @WedgeLIVE @BluehairCoffee It seemed deep enough to total some cars at 8:45. Also, 👋, neighbor.
#
#
#
# The tweet was tweeted at 2022-05-12 03:16:18+00:00.
# The original tweet has been retweeted 0 times.
# @WedgeLIVE 2200 block of Garfield. aka, the former Lake Blaisdell. https://t.co/SLm0zjjWUw
#
#
#
# The tweet was tweeted at 2022-05-11 00:47:28+00:00.
# The original tweet has been retweeted 412 times.
# RT @ThePlumLineGS: Terrific @Milbank piece vividly highlighting the long trail of lying, deception, norm-shredding, and all around bad-acti…

# %% [markdown]
# ## Pulling Follower Information
#
# In this next section of the assignment, we will pull information about the followers of your two artists. We must first get the follower IDs, then we will be able to "hydrate" the IDs, pulling the user objects for them. Once we have those user objects we will extract some fields that we can use in future analyses.
#
#
# The Twitter API only allows users to make 15 requests per 15 minutes when pulling followers. Each request allows you to gather 5000 follower ids. Tweepy will grab the 15 requests quickly then wait 15 minutes, rather than slowly pull the requests over the time period. Before we start grabbing follower IDs, let's first just check how long it would take to pull all of the followers. To do this we use the `followers_count` item from the user object.

# %%
# I'm putting the handles in a list to iterate through below
handles = ['pink', 'dual lipa']

# This will iterate through each Twitter handle that we're collecting from
for screen_name in handles:
    
    # Tells Tweepy we want information on the handle we're collecting from
    # The next line specifies which information we want, which in this case is the number of followers 
    user = api.get_user(screen_name = 'handles') 
    followers_count = user.followers_count

    # Let's see roughly how long it will take to grab all the follower IDs. 
    print(f'''
    @{screen_name} has {followers_count} followers. 
    That will take roughly {followers_count/(5000*15*4):.2f} hours to pull the followers.
    ''')
# Out:
#     @pink has 3313 followers.
#     That will take roughly 0.01 hours to pull the followers.
#
#
#     @dual lipa has 3313 followers.
#     That will take roughly 0.01 hours to pull the followers.

# %% [markdown]
# As we pull data for each artist we will write their data to a folder called "twitter", so we will make that folder if needed.

# %%
# Make the "twitter" folder here. If you'd like to practice your programming, add functionality 
# that checks to see if the folder exists. If it does, then "unlink" it. Then create a new one.

if not os.path.isdir("twitter") : 
    #shutil.rmtree("twitter/")
    os.mkdir("twitter")

# %% [markdown]
# In this following cells, use the `api.followers_ids` (and the `tweepy.Cursor` functionality) to pull some of the followers for your two artists. As you pull the data, write the follower ids to a file called `[artist name]_followers.txt` in the "twitter" folder. For instance, for Cher I would create a file named `cher_followers.txt`. As you pull the data, also store it in an object like a list or a data frame.

# %%
num_followers_to_pull = 60*1000 # feel free to use this to limit the number of followers you pull.

# %%
# Modify the below code stub to pull the follower IDs and write them to a file. 

# Grabs the time when we start making requests to the API
start_time = datetime.datetime.now()

for handle in handles :
    
        output_file = handle + "_followers.txt"
    
    
    # Pull and store the follower IDs
    
followers_ids = []
for page in tweepy.Cursor(api.get_follower_ids, screen_name="handle").pages():
    followers_ids.extend(page)
    time.sleep(60)
        

list = len(followers_ids)
print(list)
    
    # Write the IDs to the output file in the `twitter` folder.
    
with open('twitter.txt','w') as file:
    file.write(str(followers_ids))
        
        
    # If you've pulled num_followers_to_pull, feel free to break out paged twitter API response
            
        
        
# Let's see how long it took to grab all follower IDs
end_time = datetime.datetime.now()
print(end_time - start_time)
# Out:
# 0
# 0:00:00.220779

# %% [markdown]
# Now that you have your follower ids, gather some information that we can use in future assignments on them. Using the `lookup_users` function, pull the user objects for your followers. These requests are limited to 900 per 15 minutes, but you can request 100 users at a time. At 90,000 users per 15 minutes, the rate limiter on pulls might be bandwidth rather than API limits.
#
# Extract the following fields from the user object:
#
# * screen_name
# * name
# * id
# * location
# * followers_count
# * friends_count
# * description
#
# These can all be accessed via these names in the object. Store the fields with one user per row in a tab-delimited text file with the name `[artist name]_follower_data.txt`. For instance, for Cher I would create a file named `cher_follower_data.txt`.

# %%
# in this cell, do the following
# 1. Set up a data frame or dictionary to hold the user information
# 2. Use the `lookup_users` api function to pull sets of 100 users at a time

# getting the users by user_ids
users = api.lookup_users(screen_name = handle)
  
# printing the user details
for user in users:
    print("The id is : " + str(user.id))
    print("The screen name is : " + user.screen_name, end = "\n\n")

# 3. Store the listed fields in your data frame or dictionary.
# 4. Write the user information in tab-delimited form to the follower data text file.
# Out:
# The id is : 22005817
# The screen name is : u
#
# The id is : 940631
# The screen name is : a
#
# The id is : 50465434
# The screen name is : L
#
# The id is : 11046
# The screen name is : p

# %% [markdown]
# One note: the user's description can have tabs or returns in it, so make sure to clean those out of the description before writing them to the file. Here's an example of how you might do this.

# %%
tricky_description = """
    Home by Warsan Shire
    
    no one leaves home unless
    home is the mouth of a shark.
    you only run for the border
    when you see the whole city
    running as well.

"""
# This won't work in a tab-delimited text file.

clean_description = re.sub(r"\s+"," ",tricky_description)
clean_description
# Out:
# ' Home by Warsan Shire no one leaves home unless home is the mouth of a shark. you only run for the border when you see the whole city running as well. '

# %% [markdown]
# ---
#
# # Lyrics Scrape
#
# This section asks you to pull data from the Twitter API and scrape www.AZLyrics.com. In the notebooks where you do that work you are asked to store the data in specific ways.

# %%
# we'll use this dictionary to hold both the artist name and the link on AZlyrics
# my artists are "Pink" & Dua Lipa

artists = {'pink':"https://www.azlyrics.com/p/pink.html",
          'dualipa':"https://www.azlyrics.com/d/dualipa.html"}

# %% [markdown]
# ## A Note on Rate Limiting
#
# The lyrics site, www.azlyrics.com, does not have an explicit maximum on number of requests in any one time, but in our testing it appears that too many requests in too short a time will cause the site to stop returning lyrics pages. (Entertainingly, the page that gets returned seems to only have the song title to [a Tom Jones song](https://www.azlyrics.com/lyrics/tomjones/itsnotunusual.html).)
#
# Whenever you call `requests.get` to retrieve a page, put a `time.sleep(5 + 10*random.random())` on the next line. This will help you not to get blocked. If you _do_ get blocked, which you can identify if the returned pages are not correct, just request a lyrics page through your browser. You'll be asked to perform a CAPTCHA and then your requests should start working again.
#
# ## Part 1: Finding Links to Songs Lyrics
#
# That general artist page has a list of all songs for that artist with links to the individual song pages.
#
# Q: Take a look at the `robots.txt` page on www.azlyrics.com. (You can read more about these pages [here](https://developers.google.com/search/docs/advanced/robots/intro).) Is the scraping we are about to do allowed or disallowed by this page? How do you know?
#
# A: Allowed, because our URLs aren't linked from other places on the web.

# %%
# Let's set up a dictionary of lists to hold our links
lyrics_pages = defaultdict (lambda:(list))

for artist, artist_page in artists.items() :
    # request the page and sleep
    r = requests.get(artist_page)
    time.sleep(5 + 10*random.random())
    
    # now extract the links to lyrics pages from this page
    # store the links `lyrics_pages` where the key is the artist and the value is a list of links.

url = 'https://www.azlyrics.com/p/pink.html'

links = []

urls = soup.find_all(class_ = 'chartlist-name')

for url in urls:
    relative_link = url.find('a')['href']
    link = 'https://www.azlyrics.com/' + relative_link
    links.append(link)
print(links)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     359             server_hostname=server_hostname,
# --> 360             ssl_context=context,
#     361         )
#
# ~\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password)
#     369         if HAS_SNI and server_hostname is not None:
# --> 370             return context.wrap_socket(sock, server_hostname=server_hostname)
#     371
#
# ~\Anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     422             context=self,
# --> 423             session=session
#     424         )
#
# ~\Anaconda3\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     869                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 870                     self.do_handshake()
#     871             except (OSError, ValueError):
#
# ~\Anaconda3\lib\ssl.py in do_handshake(self, block)
#    1138                 self.settimeout(None)
# -> 1139             self._sslobj.do_handshake()
#    1140         finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1076)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     449                     retries=self.max_retries,
# --> 450                     timeout=timeout
#     451                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     435         if new_retry.is_exhausted():
# --> 436             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     437
#
# MaxRetryError: HTTPSConnectionPool(host='www.azlyrics.com', port=443): Max retries exceeded with url: /p/pink.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1076)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-108-4dfe013effe4> in <module>
#       4 for artist, artist_page in artists.items() :
#       5     # request the page and sleep
# ----> 6     r = requests.get(artist_page)
#       7     time.sleep(5 + 10*random.random())
#       8
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515             if isinstance(e.reason, _SSLError):
#     516                 # This branch is for urllib3 v1.22 and later.
# --> 517                 raise SSLError(e, request=request)
#     518
#     519             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='www.azlyrics.com', port=443): Max retries exceeded with url: /p/pink.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1076)')))

# %%
lyrics_pages
# Out:
# defaultdict(list, {})

# %% [markdown]
# Let's make sure we have enough lyrics pages to scrape.

# %%
for artist, lp in lyrics_pages.items() :
    assert(len(set(lp)) > 20)

# %%
# Let's see how long it's going to take to pull these lyrics 
# if we're waiting `5 + 10*random.random()` seconds 
for artist, links in lyrics_pages.items() : 
    print(f"For {artist} we have {len(links)}.")
    print(f"The full pull will take for this artist will take {round(len(links)*10/3600,2)} hours.")

# %% [markdown]
# ## Part 2: Pulling Lyrics
#
# Now that we have the links to our lyrics pages, let's go scrape them! Here are the steps for this part.
#
# 1. Create an empty folder in our repo called "lyrics".
# 1. Iterate over the artists in `lyrics_pages`.
# 1. Create a subfolder in lyrics with the artist's name. For instance, if the artist was Cher you'd have `lyrics/cher/` in your repo.
# 1. Iterate over the pages.
# 1. Request the page and extract the lyrics from the returned HTML file using BeautifulSoup.
# 1. Use the function below, `generate_filename_from_url`, to create a filename based on the lyrics page, then write the lyrics to a text file with that name.

# %%
def generate_filename_from_link(link) :
    
    if not link :
        return None
    
    # drop the http or https and the html
    name = link.replace("https","").replace("http","")
    name = link.replace(".html","")

    name = name.replace("/lyrics/","")
    
    # Replace useless chareacters with UNDERSCORE
    name = name.replace("://","").replace(".","_").replace("/","_")
    
    # tack on .txt
    name = name + ".txt"
    
    return(name)

# %%
# Make the lyrics folder here. If you'd like to practice your programming, add functionality 
# that checks to see if the folder exists. If it does, then use shutil.rmtree to remove it and create a new one.

import shutil

if os.path.isdir("lyrics") : 
    shutil.rmtree("lyrics/")

os.mkdir("lyrics")

# %%
url_stub = "https://www.azlyrics.com" 
start = time.time()

total_pages = 0 

#for artist in lyrics_pages :

    # Use this space to carry out the following steps: 
    
    # 1. Build a subfolder for the artist
    # 2. Iterate over the lyrics pages
    # 3. Request the lyrics page. 
        # Don't forget to add a line like `time.sleep(5 + 10*random.random())`
        # to sleep after making the request
    # 4. Extract the title and lyrics from the page.
    # 5. Write out the title, two returns ('\n'), and the lyrics. Use `generate_filename_from_url`
    #    to generate the filename. 
    
    
    # Remember to pull at least 20 songs per artist. It may be fun to pull all the songs for the artist.

# %%
# extracting the title from the page

r = requests.get(artist_page)
time.sleep(5 + 10*random.random())

soup = BeautifulSoup(r.text, 'html.parser')

for title in soup.find_all('title'):
    title_text = title.text
    title_text = title.text.split('-')[0]
    title_text = title.text.split('|')[0]
    title_text = title.text.replace(' Lyrics', '').strip
    
title_text

# %%
# making the request:
r = requests.get(artist_page)
time.sleep(5 + 10*random.random())

# passing to the soup
soup = BeautifulSoup(r.text, 'html.parser')

soup_boiler = 'Usage of azlyrics.com content by any third-party'

for item in soup.find_all('div'):
    if title_text in item.text:
        break
        print(item.text)

# %%
# extracting the lyrics from the page

lyrics = ''
good_line = False

for line in item.text.split('\n'):
    if title_text in line and not 'lyrics' in line:
        good_line = True
        
    if 'Submit Correction' in line:
        break
        
    if good_line:
        lyrics = lyrics + '\n' + line
        
print(lyrics.strip())

# %%
print(f"Total run time was {round((time.time() - start)/3600,2)} hours.")

# %% [markdown]
# ---
#
# # Evaluation
#
# This assignment asks you to pull data from the Twitter API and scrape www.AZLyrics.com.  After you have finished the above sections , run all the cells in this notebook. Print this to PDF and submit it, per the instructions.

# %%
# Simple word extractor from Peter Norvig: https://norvig.com/spell-correct.html
def words(text): 
    return re.findall(r'\w+', text.lower())

# %% [markdown]
# ---
#
# ## Checking Twitter Data
#
# The output from your Twitter API pull should be two files per artist, stored in files with formats like `cher_followers.txt` (a list of all follower IDs you pulled) and `cher_followers_data.txt`. These files should be in a folder named `twitter` within the repository directory. This code summarizes the information at a high level to help the instructor evaluate your work.

# %%
twitter_files = os.listdir("twitter")
twitter_files = [f for f in twitter_files if f != ".DS_Store"]
artist_handles = list(set([name.split("_")[0] for name in twitter_files]))

print(f"We see two artist handles: {artist_handles[0]} and {artist_handles[1]}.")

# %%
for artist in artist_handles :
    follower_file = artist + "_followers.txt"
    follower_data_file = artist + "_followers_data.txt"
    
    ids = open("twitter/" + follower_file,'r').readlines()
    
    print(f"We see {len(ids)-1} in your follower file for {artist}, assuming a header row.")
    
    with open("twitter/" + follower_data_file,'r') as infile :
        
        # check the headers
        headers = infile.readline().split("\t")
        
        print(f"In the follower data file ({follower_data_file}) for {artist}, we have these columns:")
        print(" : ".join(headers))
        
        description_words = []
        locations = set()
        
        
        for idx, line in enumerate(infile.readlines()) :
            line = line.strip("\n").split("\t")
            
            try : 
                locations.add(line[3])            
                description_words.extend(words(line[6]))
            except :
                pass
    
        

        print(f"We have {idx+1} data rows for {artist} in the follower data file.")

        print(f"For {artist} we have {len(locations)} unique locations.")

        print(f"For {artist} we have {len(description_words)} words in the descriptions.")
        print("Here are the five most common words:")
        print(Counter(description_words).most_common(5))

        
        print("")
        print("-"*40)
        print("")

# %% [markdown]
# ## Checking Lyrics
#
# The output from your lyrics scrape should be stored in files located in this path from the directory:
# `/lyrics/[Artist Name]/[filename from URL]`. This code summarizes the information at a high level to help the instructor evaluate your work.

# %%
artist_folders = os.listdir("lyrics/")
artist_folders = [f for f in artist_folders if os.path.isdir("lyrics/" + f)]

for artist in artist_folders : 
    artist_files = os.listdir("lyrics/" + artist)
    artist_files = [f for f in artist_files if 'txt' in f or 'csv' in f or 'tsv' in f]

    print(f"For {artist} we have {len(artist_files)} files.")

    artist_words = []

    for f_name in artist_files : 
        with open("lyrics/" + artist + "/" + f_name) as infile : 
            artist_words.extend(words(infile.read()))

            
    print(f"For {artist} we have roughly {len(artist_words)} words, {len(set(artist_words))} are unique.")
